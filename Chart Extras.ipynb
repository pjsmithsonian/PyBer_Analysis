# %%
# %matplotlib inline
# %matplotlib notebook ## makes the graphs interactive

# %%
# Import dependencies.
import matplotlib.pyplot as plt
import statistics

# %% [markdown]
# ## Error Bars to Line Chart

# %% [markdown]
# ### MATLAB Error Bar

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Get the standard deviation of the values in the y-axis.
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis, y_axis, yerr=stdev)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %% [markdown]
# ### Object Oriented Line Chart with Error Bar

# %%
fig, ax = plt.subplots()
ax.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %% [markdown]
# ## Error Bar on Bar Chart

# %% [markdown]
# ### MATLAB Approach

# %%
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %% [markdown]
# ### Object Oriented Approach

# %%
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %% [markdown]
# ## Change Major Ticks

# %%
import numpy as np
plt.barh(x_axis, y_axis)
plt.xticks(np.arange(0, 51, step=5.0)) #changes the x axis label to being 0 - 50 by 5s instead of the default 10s
plt.gca().invert_yaxis()

# %%
np.arange(0, 51, step=5.0)
# Out:
# array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45., 50.])

# %% [markdown]
# ### Object Oriented Approach to Change Major Ticks

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0)) # alternative: ax.xaxis.set_ticks(0, 51, step=5.0))
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Add Minor Ticks

# %% [markdown]
# ### Object Oriented Approach

# %%
from matplotlib.ticker import MultipleLocator

# Increase the size of the plot figure.
fix, ax = plt.subplots(figsize = (8, 8))
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))

# Create minor ticks at an increment of 1.
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()
